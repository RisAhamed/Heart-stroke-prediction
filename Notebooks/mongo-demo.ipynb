# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://Riswan:password@us-visa-cluster.dffpbxg.mongodb.net/?retryWrites=true&w=majority&appName=us-visa-cluster"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# %%
print("MONGO ")
# Out:
# MONGO

# %%
uri = "mongodb+srv://Riswan:password@123@cluster0.nsxepuw.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pandas as pd
df = pd.read_csv("data\healthcare-dataset-stroke-data.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
len(df)
# Out:
# 25480

# %%
df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import csv
import json

with open('data\healthcare-dataset-stroke-data.csv', 'r') as file:
    reader = csv.DictReader(file)
    data = [row for row in reader]
    
json_data = json.dumps(data, indent=4)
with open('output.json', 'w') as file:
    file.write(json_data)

# %%
import json
with open('output.json', 'r') as file:
    data = json.load(file)
print(data)
# Out:
# [{'id': '9046', 'gender': 'Male', 'age': '67', 'hypertension': '0', 'heart_disease': '1', 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': '228.69', 'bmi': '36.6', 'smoking_status': 'formerly smoked', 'stroke': '1'}, {'id': '51676', 'gender': 'Female', 'age': '61', 'hypertension': '0', 'heart_disease': '0', 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': '202.21', 'bmi': 'N/A', 'smoking_status': 'never smoked', 'stroke': '1'}, {'id': '31112', 'gender': 'Male', 'age': '80', 'hypertension': '0', 'heart_disease': '1', 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': '105.92', 'bmi': '32.5', 'smoking_status': 'never smoked', 'stroke': '1'}, {'id': '60182', 'gender': 'Female', 'age': '49', 'hypertension': '0', 'heart_disease': '0', 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': '171.23', 'bmi': '34.
# ...

# %%
data = df.to_dict(orient ="records")
data
# Out:
# [{'id': 9046,
#   'gender': 'Male',
#   'age': 67.0,
#   'hypertension': 0,
#   'heart_disease': 1,
#   'ever_married': 'Yes',
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 228.69,
#   'bmi': 36.6,
#   'smoking_status': 'formerly smoked',
#   'stroke': 1},
#  {'id': 51676,
#   'gender': 'Female',
#   'age': 61.0,
#   'hypertension': 0,
#   'heart_disease': 0,
#   'ever_married': 'Yes',
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 202.21,
#   'bmi': nan,
#   'smoking_status': 'never smoked',
#   'stroke': 1},
#  {'id': 31112,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': 0,
#   'heart_disease': 1,
#   'ever_married': 'Yes',
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 105.92,
#   'bmi': 32.5,
#   'smoking_status': 'never smoked',
#   'stroke': 1},
#  {'id': 60182,
#   'gender': 'Female',
#   'age': 49.0,
#   'hypertension': 0,
#   'heart_disease': 0,
# ...

# %%
len(data)
# Out:
# 25480

# %%
uri

# %%
DB_NAME = "stroke"
COLLECTION_NAME = "strokedata"
CONNECTION_URL = 'mongodb+srv://Riswan:Riswan@stroke.yqxqo.mongodb.net/?retryWrites=true&w=majority&appName=stroke'

# %%
from pymongo.mongo_client import MongoClient
import pymongo

# %%
from pymongo.mongo_client import MongoClient
# Create a new client and connect to the server
client = MongoClient(CONNECTION_URL)

# %%
# client =  MongoClient(CONNECTION_URL)
db = client['Heart-disease']

collection = db['stroke']

rec = collection.insert_many(data)
# collection
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[24], line 6
#       2 db = client['Heart-disease']
#       4 collection = db['stroke']
# ----> 6 rec = collection.insert_many(data)
#       7 # collection
#
# File c:\Users\riswa\anaconda3\envs\hstroke\lib\site-packages\pymongo\collection.py:741, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session)
#     739 blk = _Bulk(self, ordered, bypass_document_validation)
#     740 blk.ops = [doc for doc in gen()]
# --> 741 blk.execute(self.write_concern.document, session=session)
#     742 return InsertManyResult(inserted_ids, self.write_concern.acknowledged)
#
# File c:\Users\riswa\anaconda3\envs\hstroke\lib\site-packages\pymongo\bulk.py:432, in _Bulk.execute(self, write_concern, session)
#     430         self.execute_no_results(sock_info, generator)
#     431 else:
# ...

# %%
# collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('66ae4e30e36ae127659c36ae'), ObjectId('66ae4e30e36ae127659c36af'), ObjectId('66ae4e30e36ae127659c36b0'), ObjectId('66ae4e30e36ae127659c36b1'), ObjectId('66ae4e30e36ae127659c36b2'), ObjectId('66ae4e30e36ae127659c36b3'), ObjectId('66ae4e30e36ae127659c36b4'), ObjectId('66ae4e30e36ae127659c36b5'), ObjectId('66ae4e30e36ae127659c36b6'), ObjectId('66ae4e30e36ae127659c36b7'), ObjectId('66ae4e30e36ae127659c36b8'), ObjectId('66ae4e30e36ae127659c36b9'), ObjectId('66ae4e30e36ae127659c36ba'), ObjectId('66ae4e30e36ae127659c36bb'), ObjectId('66ae4e30e36ae127659c36bc'), ObjectId('66ae4e30e36ae127659c36bd'), ObjectId('66ae4e30e36ae127659c36be'), ObjectId('66ae4e30e36ae127659c36bf'), ObjectId('66ae4e30e36ae127659c36c0'), ObjectId('66ae4e30e36ae127659c36c1'), ObjectId('66ae4e30e36ae127659c36c2'), ObjectId('66ae4e30e36ae127659c36c3'), ObjectId('66ae4e30e36ae127659c36c4'), ObjectId('66ae4e30e36ae127659c36c5'), ObjectId('66ae4e30e36ae127659c36c6'), ObjectId('66ae4e30e36ae127659c
# ...

# %%
collection.find()

# %%
for i,j in enumerate(collection.find()):
    print(i,j)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 for i,j in enumerate(collection.find()):
#       2     print(i,j)
#
# File c:\Users\riswa\anaconda3\envs\hstroke\lib\site-packages\pymongo\cursor.py:1176, in Cursor.next(self)
#    1174 if self.__empty:
#    1175     raise StopIteration
# -> 1176 if len(self.__data) or self._refresh():
#    1177     if self.__manipulate:
#    1178         _db = self.__collection.database
#
# File c:\Users\riswa\anaconda3\envs\hstroke\lib\site-packages\pymongo\cursor.py:1087, in Cursor._refresh(self)
#    1072 if self.__id is None:  # Query
#    1073     q = self._query_class(self.__query_flags,
#    1074                           self.__collection.database.name,
#    1075                           self.__collection.name,
#    (...)
#    1085                           self.__session,
# ...

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for i, j in enumerate(records):
#       2     print(f"{i}: {j}")
#
# File c:\Users\riswa\anaconda3\envs\mlops\lib\site-packages\pymongo\cursor.py:1176, in Cursor.next(self)
#    1174 if self.__empty:
#    1175     raise StopIteration
# -> 1176 if len(self.__data) or self._refresh():
#    1177     if self.__manipulate:
#    1178         _db = self.__collection.database
#
# File c:\Users\riswa\anaconda3\envs\mlops\lib\site-packages\pymongo\cursor.py:1087, in Cursor._refresh(self)
#    1072 if self.__id is None:  # Query
#    1073     q = self._query_class(self.__query_flags,
#    1074                           self.__collection.database.name,
#    1075                           self.__collection.name,
#    (...)
#    1085                           self.__session,
# ...

# %%
list(collection.find())

collection.count_documents({})
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 list(collection.find())
#       3 collection.count_documents({})
#
# File c:\Users\riswa\anaconda3\envs\hstroke\lib\site-packages\pymongo\cursor.py:1176, in Cursor.next(self)
#    1174 if self.__empty:
#    1175     raise StopIteration
# -> 1176 if len(self.__data) or self._refresh():
#    1177     if self.__manipulate:
#    1178         _db = self.__collection.database
#
# File c:\Users\riswa\anaconda3\envs\hstroke\lib\site-packages\pymongo\cursor.py:1087, in Cursor._refresh(self)
#    1072 if self.__id is None:  # Query
#    1073     q = self._query_class(self.__query_flags,
#    1074                           self.__collection.database.name,
#    1075                           self.__collection.name,
#    (...)
#    1085                           self.__session,
# ...

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  66ae4e30e36ae127659c36ae  EZYV01      Asia           High School
# 1  66ae4e30e36ae127659c36af  EZYV02      Asia              Master's
# 2  66ae4e30e36ae127659c36b0  EZYV03      Asia            Bachelor's
# 3  66ae4e30e36ae127659c36b1  EZYV04      Asia            Bachelor's
# 4  66ae4e30e36ae127659c36b2  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# ...

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
from pymongo.mongo_client import MongoClient

uri = 'mongodb://Riswan:Riswan@ac-jeaupca-shard-00-00.dffpbxg.mongodb.net:27017,ac-jeaupca-shard-00-01.dffpbxg.mongodb.net:27017,ac-jeaupca-shard-00-02.dffpbxg.mongodb.net:27017/?ssl=true&replicaSet=atlas-ly4yb1-shard-0&authSource=admin&retryWrites=true&w=majority&appName=us-visa-cluster'
# Create a new client and connect to the server
client = MongoClient(uri)
db = MongoClient(uri).get_database()
print(db.name)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
    client.find_
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[21], line 6
#       4 # Create a new client and connect to the server
#       5 client = MongoClient(uri)
# ----> 6 db = MongoClient(uri).get_database()
#       7 print(db.name)
#       8 # Send a ping to confirm a successful connection
#
# File c:\Users\riswa\anaconda3\envs\mlops\lib\site-packages\pymongo\mongo_client.py:1613, in MongoClient.get_database(self, name, codec_options, read_preference, write_concern, read_concern)
#    1611 if name is None:
#    1612     if self.__default_database_name is None:
# -> 1613         raise ConfigurationError('No default database defined')
#    1614     name = self.__default_database_name
#    1616 return database.Database(
#    1617     self, name, codec_options, read_preference,
#    1618     write_concern, read_concern)
#
# ConfigurationError: No default database defined
